# %% [markdown]
# # Billion Dollar Disasters Data Cleaning

# %% [markdown]
# ### In this notebook, I read in the scraped data from Billion Dollar Disasters and do some cleaning in the Pandas library.

# %%
import pandas as pd

# %%
df = pd.read_csv('billion_dollar_disasters_scrape.csv')
df.head()
# Out:
#                                           event_name     disaster_type  \
# 0  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 1  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 2                                   Hurricane Milton  Tropical Cyclone
# 3                                   Hurricane Milton  Tropical Cyclone
# 4                                   Hurricane Helene  Tropical Cyclone
#
#      begin_date      end_date  \
# 0   Jan 1, 2024  Dec 31, 2024
# 1   Jan 1, 2024  Dec 31, 2024
# 2   Oct 9, 2024  Oct 10, 2024
# 3   Oct 9, 2024  Oct 10, 2024
# 4  Sep 24, 2024  Sep 29, 2024
#
#                                              details      cost deaths
# 0  Drought conditions impacted many Southern, Eas...   $5.4 CI    136
# 1  Drought conditions impacted many Southern, Eas...   $5.3 CI    136
# 2  Category 3 Hurricane Milton with 120 mph susta...  $34.3 CI     32
# 3  Category 3 Hurricane Milton with 120 mph susta...  $34.3 CI     32
# 4  Category 4 Hurricane Helene with 140 mph susta...  $78.7 CI    219

# %%
df.rename(columns={'cost': 'est_cost_billionUSD_CPI-adjusted'}, inplace=True)

# %%
import re

df['begin_year'] = df['begin_date'].str.extract(r', (\d{4})')
df['end_year'] = df['end_date'].str.extract(r', (\d{4})')
df.head()
# Out:
#                                           event_name     disaster_type  \
# 0  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 1  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 2                                   Hurricane Milton  Tropical Cyclone
# 3                                   Hurricane Milton  Tropical Cyclone
# 4                                   Hurricane Helene  Tropical Cyclone
#
#      begin_date      end_date  \
# 0   Jan 1, 2024  Dec 31, 2024
# 1   Jan 1, 2024  Dec 31, 2024
# 2   Oct 9, 2024  Oct 10, 2024
# 3   Oct 9, 2024  Oct 10, 2024
# 4  Sep 24, 2024  Sep 29, 2024
#
#                                              details  \
# 0  Drought conditions impacted many Southern, Eas...
# 1  Drought conditions impacted many Southern, Eas...
# 2  Category 3 Hurricane Milton with 120 mph susta...
# 3  Category 3 Hurricane Milton with 120 mph susta...
# 4  Category 4 Hurricane Helene with 140 mph susta...
#
#   est_cost_billionUSD_CPI-adjusted deaths begin_year end_year
# 0                          $5.4 CI    136       2024     2024
# 1                          $5.3 CI    136       2024     2024
# 2                         $34.3 CI     32       2024     2024
# 3                         $34.3 CI     32       2024     2024
# 4                         $78.7 CI    219       2024     2024

# %%
df['est_cost_billionUSD_CPI-adjusted'] = df['est_cost_billionUSD_CPI-adjusted'].str.replace('$', '') 
df['est_cost_billionUSD_CPI-adjusted'] = df['est_cost_billionUSD_CPI-adjusted'].str.replace(' CI', '')
df['est_cost_billionUSD_CPI-adjusted'] = df['est_cost_billionUSD_CPI-adjusted'].str.replace('*', '')
df.head()
# Out:
#                                           event_name     disaster_type  \
# 0  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 1  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 2                                   Hurricane Milton  Tropical Cyclone
# 3                                   Hurricane Milton  Tropical Cyclone
# 4                                   Hurricane Helene  Tropical Cyclone
#
#      begin_date      end_date  \
# 0   Jan 1, 2024  Dec 31, 2024
# 1   Jan 1, 2024  Dec 31, 2024
# 2   Oct 9, 2024  Oct 10, 2024
# 3   Oct 9, 2024  Oct 10, 2024
# 4  Sep 24, 2024  Sep 29, 2024
#
#                                              details  \
# 0  Drought conditions impacted many Southern, Eas...
# 1  Drought conditions impacted many Southern, Eas...
# 2  Category 3 Hurricane Milton with 120 mph susta...
# 3  Category 3 Hurricane Milton with 120 mph susta...
# 4  Category 4 Hurricane Helene with 140 mph susta...
#
#   est_cost_billionUSD_CPI-adjusted deaths begin_year end_year
# 0                              5.4    136       2024     2024
# 1                              5.3    136       2024     2024
# 2                             34.3     32       2024     2024
# 3                             34.3     32       2024     2024
# 4                             78.7    219       2024     2024

# %%
df['est_cost_billionUSD_CPI-adjusted'] = df['est_cost_billionUSD_CPI-adjusted'].astype(float)

# %%
df['deaths'] = df['deaths'].str.replace(',', '')

# %%
df['deaths'] = df['deaths'].astype(int)

# %%
df['begin_date'] = pd.to_datetime(df['begin_date'])
df['end_date'] = pd.to_datetime(df['end_date'])

# %%
df['disaster_length_days'] = (df['end_date'] - df['begin_date']).dt.days
df.head()
# Out:
#                                           event_name     disaster_type  \
# 0  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 1  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 2                                   Hurricane Milton  Tropical Cyclone
# 3                                   Hurricane Milton  Tropical Cyclone
# 4                                   Hurricane Helene  Tropical Cyclone
#
#   begin_date begin_year   end_date end_year  disaster_length_days  \
# 0 2024-01-01       2024 2024-12-31     2024                   365
# 1 2024-01-01       2024 2024-12-31     2024                   365
# 2 2024-10-09       2024 2024-10-10     2024                     1
# 3 2024-10-09       2024 2024-10-10     2024                     1
# 4 2024-09-24       2024 2024-09-29     2024                     5
#
#                                              details  \
# 0  Drought conditions impacted many Southern, Eas...
# 1  Drought conditions impacted many Southern, Eas...
# 2  Category 3 Hurricane Milton with 120 mph susta...
# 3  Category 3 Hurricane Milton with 120 mph susta...
# 4  Category 4 Hurricane Helene with 140 mph susta...
#
#    est_cost_billionUSD_CPI-adjusted  deaths
# 0                               5.4     136
# 1                               5.3     136
# 2                              34.3      32
# 3                              34.3      32
# 4                              78.7     219

# %%
col = df.pop('begin_year')  
df.insert(3, 'begin_year', col)

# %%
col = df.pop('end_year')  
df.insert(5, 'end_year', col)  
df.head()
# Out:
#                                           event_name     disaster_type  \
# 0  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 1  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 2                                   Hurricane Milton  Tropical Cyclone
# 3                                   Hurricane Milton  Tropical Cyclone
# 4                                   Hurricane Helene  Tropical Cyclone
#
#   begin_date begin_year   end_date end_year  disaster_length_days  \
# 0 2024-01-01       2024 2024-12-31     2024                   365
# 1 2024-01-01       2024 2024-12-31     2024                   365
# 2 2024-10-09       2024 2024-10-10     2024                     1
# 3 2024-10-09       2024 2024-10-10     2024                     1
# 4 2024-09-24       2024 2024-09-29     2024                     5
#
#                                              details  \
# 0  Drought conditions impacted many Southern, Eas...
# 1  Drought conditions impacted many Southern, Eas...
# 2  Category 3 Hurricane Milton with 120 mph susta...
# 3  Category 3 Hurricane Milton with 120 mph susta...
# 4  Category 4 Hurricane Helene with 140 mph susta...
#
#    est_cost_billionUSD_CPI-adjusted  deaths
# 0                               5.4     136
# 1                               5.3     136
# 2                              34.3      32
# 3                              34.3      32
# 4                              78.7     219

# %%
col = df.pop('disaster_length_days')  
df.insert(6, 'disaster_length_days', col)  
df.head()
# Out:
#                                           event_name     disaster_type  \
# 0  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 1  Southern/Eastern/Northwestern Drought and Heat...           Drought
# 2                                   Hurricane Milton  Tropical Cyclone
# 3                                   Hurricane Milton  Tropical Cyclone
# 4                                   Hurricane Helene  Tropical Cyclone
#
#   begin_date begin_year   end_date end_year  disaster_length_days  \
# 0 2024-01-01       2024 2024-12-31     2024                   365
# 1 2024-01-01       2024 2024-12-31     2024                   365
# 2 2024-10-09       2024 2024-10-10     2024                     1
# 3 2024-10-09       2024 2024-10-10     2024                     1
# 4 2024-09-24       2024 2024-09-29     2024                     5
#
#                                              details  \
# 0  Drought conditions impacted many Southern, Eas...
# 1  Drought conditions impacted many Southern, Eas...
# 2  Category 3 Hurricane Milton with 120 mph susta...
# 3  Category 3 Hurricane Milton with 120 mph susta...
# 4  Category 4 Hurricane Helene with 140 mph susta...
#
#    est_cost_billionUSD_CPI-adjusted  deaths
# 0                               5.4     136
# 1                               5.3     136
# 2                              34.3      32
# 3                              34.3      32
# 4                              78.7     219

# %%
df.dtypes
# Out:
# event_name                                  object
# disaster_type                               object
# begin_date                          datetime64[ns]
# begin_year                                  object
# end_date                            datetime64[ns]
# end_year                                    object
# disaster_length_days                         int64
# details                                     object
# est_cost_billionUSD_CPI-adjusted           float64
# deaths                                       int64
# dtype: object

# %%
df.to_csv('billion_dollar_disasters_cleaned.csv')
